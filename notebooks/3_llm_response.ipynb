# %%
import re
import os
import pandas as pd

from google import genai

from utils import *

from dotenv import load_dotenv


pd.set_option('display.max_columns', None)

load_dotenv()
# Out:
# True

# %%
gemini_key = os.getenv("GEMINI_API_KEY")

# %%
tests = [
    # email + teléfono + nombre
    "Contactar a Juan Perez al +57 300-123-4567 o jperez@mail.com para validar.",
    # dirección + nombre
    "La propiedad está en 135 Abbott St y el responsable es Maria Lopez.",
    # caso que quede vacío
    "Juan Perez, +57 300-123-4567, jperez@mail.com, 22 Main Street"
]

res = [sanitizar_texto(txt) for txt in tests]

# %% [markdown]
# # Salida estructurada

# %%
casos_prueba = [
    {
        "id_propiedad": "077-0044-0000",
        "nivel_alerta": "ALTA",
        "motivo": "Inconsistencia detectada. Llamar a Maria Lopez al (301) 555-0199 para confirmar datos.",
        "recomendacion": "Verificar en Calle 123 #45-67 y escribir a mlopez@ejemplo.com para soporte.",
    },
    {
        "id_propiedad": "030-0452-0000",
        "nivel_alerta": "MEDIA",
        "motivo": "Posible error de clasificación. Contactar a Carlos Perez al +57 310-555-0000.",
        "recomendacion": "Solicitar documentación adicional al correo carlos.perez@correo.co y ajustar registro si aplica.",
    },
    {
        "id_propiedad": "015-0467-0000",
        "nivel_alerta": "BAJA",
        "motivo": "Caso atípico por ubicación. Responsable: Ana Gomez, teléfono 3001234567.",
        "recomendacion": "Revisar historial de pagos y enviar notificación a ana.gomez@mail.com con pasos a seguir.",
    },
    {
        "id_propiedad":"077-0144-0000",
        "nivel_alerta": "CRITICA",
        "motivo":"Juan Perez, +57 300-123-4567, jperez@mail.com, Calle 123 #45-67",
        "recomendacion":"Calle 60N #12C-08"
    }
]

for caso in casos_prueba:
    print(salida_estructurada(caso))
# Out:
# {'id_propiedad': '077-0044-0000', 'nivel_alerta': 'ALTA', 'motivo_tecnico': 'Inconsistencia detectada. Llamar a [NAME] al ([PHONE] para confirmar datos', 'recomendacion': 'Verificar en [ADDRESS] y escribir a [EMAIL] para soporte'}
# {'id_propiedad': '030-0452-0000', 'nivel_alerta': 'MEDIA', 'motivo_tecnico': 'Posible error de clasificación. Contactar a [NAME] al +[PHONE]', 'recomendacion': 'Solicitar documentación adicional al correo [EMAIL] y ajustar registro si aplica'}
# {'id_propiedad': '015-0467-0000', 'nivel_alerta': 'BAJA', 'motivo_tecnico': 'Caso atípico por ubicación. Responsable: [NAME], teléfono [PHONE]', 'recomendacion': 'Revisar historial de pagos y enviar notificación a [EMAIL] con pasos a seguir'}
# {'id_propiedad': '077-0144-0000', 'nivel_alerta': 'CRITICA', 'motivo_tecnico': 'SIN_DESCRIPCION_TRAS_SANITIZACION', 'recomendacion': 'SIN_DESCRIPCION_TRAS_SANITIZACION'}

# %% [markdown]
# # Explicación con LLM

# %%
data_path = "../data/"
file_name = "df_pred_test.csv"
file_full_name = "2024_Property_Tax_Roll.csv"
labels = [ 1,  2,  3,  4,  5,  6,  7, 10, 12, 13, 14, 23, 24, 33, 70, 71, 72, 73, 74, 75, 76, 78, 79, 80, 82, 83, 84]

df_full = pd.read_csv(data_path + file_full_name)
df_final = pd.read_csv(data_path + file_name)
df_final.shape
# Out:
# (8807, 37)

# %%
df_final.head()
# Out:
#       P_ID        TAX_MAP  plat    lot  unit  CLASS               SHORT_DESC  \
# 0    628.0  005-0315-0000   5.0  315.0  0000   13.0  Residential Vacant Land
# 1  29585.0  077-0417-0000  77.0  417.0  0000    1.0            Single Family
# 2  33245.0  086-0452-0000  86.0  452.0  0000    1.0            Single Family
# 3   3804.0  013-0212-0000  13.0  212.0  0000    1.0            Single Family
# 4  21213.0  059-0264-0000  59.0  264.0  0000    1.0            Single Family
#
#   LEVY_CODE_1 SHORT_DESC 1  CIVIC        STREET SUFFIX  FORMATED_ADDRESS  \
# 0        NO01         NO01    1.0        Steele     St       1 Steele St
# 1        NO01         NO01   29.0      Windmill     St    29 Windmill St
# 2        OO01         OO01  124.0  Freeman Pkwy    NaN  124 Freeman Pkwy
# 3        OO01         OO01   67.0       Manning     St     67 Manning St
# 4        OO01         OO01   74.0         Homer     St       74 Homer St
#
#          CITY ZIP_POSTAL FIRST_NAME  LAST_NAME COMPANY  \
# 0  Providence      02906     Nathan  Applegate     NaN
# 1  Providence      02904       Liam     Mallon     NaN
# 2  Providence      02906      Helen    Burnham     NaN
# 3  Providence      02906      David       Ward     NaN
# 4  Providence      02905     STEVEN     DACRUZ     NaN
#
#                              FREE_LINE_2 CIVIC 1              STREET 1  \
# 0                        70 Evergreen St      70             Evergreen
# 1                         29 Windmill St      29              Windmill
# 2  Helen Metcalf Burnham Revocable Trust     124          Freeman Pkwy
# 3                 c/o Tiedemann Advisors     601  Union St, Suite 3315
# 4                           74  HOMER ST      74                 HOMER
#
#   S_SUFFIX UNIT      CITY 1 STATE ZIP_POSTAL 1  TOTAL_ASSMT  TOTAL_EXEMPT  \
# 0       St  NaN  Providence    RI        02906      73700.0           0.0
# 1       St  NaN  Providence    RI        02904     252300.0           0.0
# 2      NaN  NaN  Providence    RI        02906    1483700.0           0.0
# 3      NaN  NaN     Seattle    WA        98101    1975100.0           0.0
# 4       ST  NaN  PROVIDENCE    RI   02905-1321     269100.0       71992.0
#
#    TOTAL_TAXES                   Property_Location        lon        lat  \
# 0      1352.40  POINT (-71.403665419 41.846115898) -71.403665  41.846116
# 1      4629.72   POINT (-71.41789503 41.854803004) -71.417895  41.854803
# 2     15518.76  POINT (-71.393158022 41.837744993) -71.393158  41.837745
# 3     20658.56  POINT (-71.394910007 41.826489019) -71.394910  41.826489
# 4      2061.68  POINT (-71.406669985 41.787739984) -71.406670  41.787740
#
#    geo_cluster    p_true  pred_class  \
# 0            3  0.976598          13
# 1            4  0.574853           1
# 2            3  0.986904           1
# 3            2  0.831954           1
# 4            6  0.966079           1
#
#                                         y_proba_full nivel_alerta
# 0  {13: 0.9765976071357727, 23: 0.022168284282088...         BAJA
# 1  {1: 0.5748528242111206, 2: 0.42151743173599243...      CRITICA
# 2  {1: 0.9869039058685303, 2: 0.01208311785012483...         BAJA
# 3  {1: 0.8319536447525024, 2: 0.10607580095529556...         ALTA
# 4  {1: 0.9660785794258118, 2: 0.03361643105745315...        MEDIA

# %% [markdown]
# #### Generación de paquete para entregar al LLM

# %%
# Se realiza el llamado al LLM a 14 registros (permitidos por API key gratis)
df_fool = df_final.sample(frac=0.00225)
dict_alerta_info = df_fool.groupby("nivel_alerta")["p_true"].agg(median="median").to_dict()

df_fool.loc[:,"evidencia_registro"] = df_fool.apply(lambda x: build_evidence_packet(x, df_full, dict_alerta_info), axis = 1)

# %% [markdown]
# # Explicación de elección del modelo
# - Se decidió elegir el modelo gemini-2.5-flash por encima de otros modelos por:
#   * Facilidad de montaje(tiene API gratuita sin algún tipo de crédito).
#   * Recibe prompt instruccional, por lo que es fácil y rápido crearlo y modificarlo. Además de que el prompt es muy amigable con el usuario, en el sentido de que se acerca mucho a la manera en como un ser humano podría generar instrucciones para realizar algo.
#     + Por ejemplo, un modelo LLaMA requeriría instrucciones más detalladas y con un alto nivel de especificidad para lograr el mismo funcionamiento del modelo elegido que requiere un prompt más sencillo.
#   * El modelo es confiable a niveles generales, por lo que el prompt no debe ser muy estructurado ni específico para que fucione bien
#
# - Considerando el tipo de información y respuesta que debe de arrojar el modelo, elegiría gpt-5.2, gemini-3 o claude-4.  Estos modelos no requieren tanto detalle en el prompt, y son ideales realizando tareas complejas y encadenadas.

# %%
evidencia_registro = df_fool["evidencia_registro"].values
client = genai.Client(api_key=gemini_key)
model = "gemini-2.5-flash"
respuesta = []
for registro in evidencia_registro:
    print(registro)
    respuesta.append(genera_respuesta(client, registro, model))
# Out:
# {'id_propiedad': 21775, 'nivel_alerta': 'BAJA', 'grupos_p_true': {'median': {'ALTA': 0.726185375, 'BAJA': 0.9954313, 'CRITICA': 0.3068909, 'MEDIA': 0.94942975}}, 'info_user': {'full_name': 'Diogenes Ciriaco', 'address': '103-13 Otis Ave Apt 1'}, 'modelo': {'class_registrada': 2, 'class_predicha': 2, 'class_pred_top1': 2, 'p_true': 0.97628343, 'p_pred_max': 0.9762834310531616, 'p_margin': 1.0531616689846146e-09, 'top_k': [(2, 0.9762834310531616), (1, 0.023470457643270493), (23, 0.0001320694718742743), (3, 1.969322511286009e-05), (4, 1.4173693671182264e-05)]}, 'tributario': {'total_assmt': 371500.0, 'total_exempt': 0.0, 'total_taxes': 6817.04, 'tax_rate': 0.018350040376850604, 'exempt_rate': 0.0, 'assmt_pct_in_class_reg': 0.572092358281507, 'taxes_pct_in_class_reg': 0.7452998784759454, 'exempt_pct_in_class_reg': 0.9066409321609836, 'flags': []}, 'ubicacion': {'zip': '02907', 'geo_cluster': 6}, 'administrativo': {'levy_code_1': 'NO01'}, 'descripcion': {'short_desc': '2 -5 Family'}}
# {'id_propiedad': 35595, 'nivel_alerta': 'CRITICA', 'grupos_p_true': {'median': {'ALTA': 0.726185375, 'BAJA': 0.9954313, 'CRITICA': 0.3068909, 'MEDIA': 0.94942975}}, 'info_user': {'full_name': 'Frances MAGNER', 'address': 'Frances Magner Rev Intervivos Trust'}, 'modelo': {'class_registrada': 1, 'class_predicha': 2, 'class_pred_top1': 2, 'p_true': 0
', 'grupos_p_true': {'median': {'ALTA': 0.726185375, 'BAJA': 0.9954313, 'CRITICA': 0.3068909, 'MEDIA': 0.94942975}}, 'info_user': {'full_name': 'Fred Galpern', 'address': '117 Colonial Rd'}, 'modelo': {'class_registrada': 1, 'class_predicha': 1, 'class_pred_top1': 1, 'p_true': 0.77419215, 'p_pred_max': 0.7741921544075012, 'p_margin': 4.407501252856605e-09, 'top_k': [(1, 0.7741921544075012), (2, 0.2180938571691513), (23, 0.0074399737641215324), (4, 4.027617251267657e-05), (14, 2.660879363247659e-05)]}, 'tributario': {'total_assmt': 484000.0, 'total_exempt': 0.0, 'total_taxes': 5062.4, 'tax_rate': 0.010459504132231404, 'exempt_rate': 0.0, 'assmt_pct_in_class_reg': 0.7891341256366723, 'taxes_pct_in_class_reg': 0.7231239388794567, 'exempt_pct_in_class_reg': 0.8136502546689304, 'flags': []}, 'ubicacion': {'zip': '02906', 'geo_cluster': 3}, 'administrativo': {'levy_code_1': 'OO01'}, 'descripcion': {'short_desc': 'Single Family'}}
# {'id_propiedad': 13910, 'nivel_alerta': 'CRITICA', 'grupos_p_true': {'median': {'ALTA': 0.726185375, 'BAJA': 0.9954313, 'CRITICA': 0.3068909, 'MEDIA': 0.94942975}}, 'info_user': {'full_name': 'Michael Watkinson', 'address': '52 Nisbet St'}, 'modelo': {'class_registrada': 2, 'class_predicha': 1, 'class_pred_top1': 1, 'p_true': 0.06363797, 'p_pred_max': 0.7582069039344788, 'p_margin': 0.6945689339344787, 'top_k': [(1, 0.7582069039344788), (23, 0.17761872708797455), (2, 0.06363797187805176), (71, 6.941843457752839e-05), (3, 4.070979048265144e-05)]}, 'tributario': {'total_assmt': 1061100.0, 'total_exempt': 14628.0, 'total_taxes': 10945.6, 'tax_rate': 0.010315333144849684, 'exempt_rate': 0.013785694091037602, 'assmt_pct_in_class_reg': 0.9920651940810636, 'taxes_pct_in_class_reg': 0.9418114232611338, 'exempt_pct_in_class_reg': 0.9158624633640717, 'flags': ['avaluo_extremo_para_clase']}, 'ubicacion': {'zip': 'nan', 'geo_cluster': 2}, 'administrativo': {'levy_code_1': 'OO01'}, 'descripcion': {'short_desc': '2 -5 Family'}}
# {'id_propiedad': 45285, 'nivel_alerta': 'BAJA', 'grupos_p_true': {'median': {'ALTA': 0.726185375, 'BAJA': 0.9954313, 'CRITICA': 0.3068909, 'MEDIA': 0.94942975}}, 'info_user': {'full_name': 'Henry Verducci', 'address': 'Verducci Family Revo Tr'}, 'modelo': {'class_registrada': 13, 'class_predicha': 13, 'class_pred_top1': 13, 'p_true': 0.99599874, 'p_pred_max': 0.995998740196228, 'p_margin': 1.9622803382191023e-10, 'top_k': [(13, 0.995998740196228), (1, 0.003577267983928323), (23, 0.0003374505613464862), (2, 3.700811430462636e-05), (14, 2.6114283173228614e-05)]}, 'tributario': {'total_assmt': 36700.0, 'total_exempt': 0.0, 'total_taxes': 673.48, 'tax_rate': 0.018350953678474113, 'exempt_rate': 0.0, 'assmt_pct_in_class_reg': 0.7965211683623236, 'taxes_pct_in_class_reg': 0.7965211683623236, 'exempt_pct_in_class_reg': 0.9977026583524778, 'flags': []}, 'ubicacion': {'zip': '02908', 'geo_cluster': 5}, 'administrativo': {'levy_code_1': 'NO01'}, 'descripcion': {'short_desc': 'Residential Vacant Land'}}

# %%
df_fool.loc[:,"respuesta_llm"] = respuesta

# %%
df_fool.to_csv(data_path+"df_respuesta_final.csv", index=False)
